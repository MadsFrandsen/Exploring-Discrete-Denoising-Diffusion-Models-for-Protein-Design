# %%
import os
import torch
import torchvision
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
from torchvision.utils import save_image
from tqdm import tqdm

from model import UNet
from diffusion_discrete import DiscreteDiffusion, generate_betas

# %%
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)
# Out:
# device: cpu

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
torch.manual_seed(50)

# training parameters
num_epochs = 10
batch_size = 128
lr = 2e-4
model = UNet(image_channels=1).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
print("Number of model parameters: ", count_parameters(model))
print(model)
# Out:
# Number of model parameters:  168897282
# UNet(
#   (image_proj): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (time_emb): TimeEmbedding(
#     (lin1): Linear(in_features=64, out_features=256, bias=True)
#     (act): Swish()
#     (lin2): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (down): ModuleList(
#     (0-1): 2 x DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Identity()
#         (time_emb): Linear(in_features=256, out_features=64, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (2): Downsample(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (3): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=128, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (4): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Identity()
#         (time_emb): Linear(in_features=256, out_features=128, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (5): Downsample(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (6): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=256, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (projection): Linear(in_features=256, out_features=768, bias=True)
#         (output): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (7): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Identity()
#         (time_emb): Linear(in_features=256, out_features=256, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (projection): Linear(in_features=256, out_features=768, bias=True)
#         (output): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (8): Downsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (9): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(256, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (projection): Linear(in_features=1024, out_features=3072, bias=True)
#         (output): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#     )
#     (10): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Identity()
#         (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (projection): Linear(in_features=1024, out_features=3072, bias=True)
#         (output): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#     )
#   )
#   (middle): MiddleBlock(
#     (res1): ResidualBlock(
#       (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (act1): Swish()
#       (conv1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (act2): Swish()
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Identity()
#       (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#       (time_act): Swish()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (attn): AttentionBlock(
#       (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (projection): Linear(in_features=1024, out_features=3072, bias=True)
#       (output): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (res2): ResidualBlock(
#       (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (act1): Swish()
#       (conv1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (act2): Swish()
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Identity()
#       (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#       (time_act): Swish()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (up): ModuleList(
#     (0-1): 2 x UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 2048, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(2048, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (projection): Linear(in_features=1024, out_features=3072, bias=True)
#         (output): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#     )
#     (2): UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 1280, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(1280, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=256, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (projection): Linear(in_features=256, out_features=768, bias=True)
#         (output): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (3): Upsample(
#       (conv): ConvTranspose2d(256, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (4-5): 2 x UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=256, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (projection): Linear(in_features=256, out_features=768, bias=True)
#         (output): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (6): UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 384, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=128, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (projection): Linear(in_features=128, out_features=384, bias=True)
#         (output): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (7): Upsample(
#       (conv): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (8-9): 2 x UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=128, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (10): UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=64, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (11): Upsample(
#       (conv): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (12-14): 3 x UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=64, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#   )
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): Swish()
#   (final): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
# change image size from 28 to 32 so that it is power of 2
img_size = 32

transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
])

trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True)

# %%
betas = generate_betas(type='cosine', start=0.02, stop=1., num_steps=1000).to(device)

# %%
diffusion = DiscreteDiffusion(betas=betas, transition_mat_type='uniform',
                              num_bits=8, transition_bands=None, model_prediction='x_start',
                              model_output='logistic_pars', loss_type='hybrid',
                              hybrid_coeff=0.001, device=device)
# Out:
# /Users/madsfrandsen/Documents/BSc_project/diffusion_2/diffusion_discrete.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.betas = betas = torch.tensor(betas, dtype=torch.float64)

# %%
model.train()
for e in range(1, num_epochs+1):
    train_loss = 0
    train_loss_vals = []
    train_prior_bpd = 0
    for batch_idx, (x, _) in tqdm(enumerate(train_loader), total=len(train_loader)):
        x = x.int().to(device)
        optimizer.zero_grad()
        
        loss = diffusion.training_losses(model, x_start=x, rng=25).mean()
        prior_bpd = diffusion.prior_bpd(x).mean()

        loss.backward()
        train_loss += loss.item()
        train_prior_bpd += prior_bpd
        train_loss_vals.append(train_loss)
        optimizer.step()
        

    print("\tEpoch,", e, "complete!", "\tLoss: ", train_loss / batch_idx,
          "\tPrior bpd: ", train_prior_bpd / batch_idx)
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# x:  torch.Size([128, 1, 32, 32, 256])
# t:  torch.Size([128])
# a:  torch.Size([1000, 256, 256])
# a[t]:  torch.Size([128, 256, 256])
# out:  torch.Size([128, 1, 32, 32, 256])
# /Users/madsfrandsen/Documents/BSc_project/diffusion_2/utils.py:89: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   log_probs = F.log_softmax(logits)
#   0%|          | 0/469 [00:49<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 11
#       8 optimizer.zero_grad()
#      10 loss = diffusion.training_losses(model, x_start=x, rng=25).mean()
# ---> 11 prior_bpd = diffusion.prior_bpd(x).mean()
#      13 loss.backward()
#      14 train_loss += loss.item()
#
# File ~/Documents/BSc_project/diffusion_2/diffusion_discrete.py:438, in DiscreteDiffusion.prior_bpd(self, x_start)
#     436 def prior_bpd(self, x_start):
#     437     """KL(q(x_{T-1}|x_start)|| U(x_{T-1}|0, num_pixel_vals-1))."""
# --> 438     q_probs = self.q_probs(
#     439         x_start=x_start,
#     440         t = torch.full((x_start.shape[0],), self.num_timesteps - 1))
#     442     if self.transition_mat_type in ['gaussian', 'uniform']:
#     443         # Stationary distribution is a uniform distribution over all pixel values.
#     444         prior_probs = torch.ones_like(q_probs) / self.num_pixel_vals
#
# File ~/Documents/BSc_project/diffusion_2/diffusion_discrete.py:213, in DiscreteDiffusion.q_probs(self, x_start, t)
#     200 def q_probs(self, x_start, t):
#     201     """Compute probabilities of q(x_t | x_start).
#     202
#     203     Args:
#    (...)
#     211                                             num_pixel_vals).
#     212     """
# --> 213     return self._at(self.q_mats, t, x_start)
#
# File ~/Documents/BSc_project/diffusion_2/diffusion_discrete.py:160, in DiscreteDiffusion._at(self, a, t, x)
#     147 def _at(self, a, t, x):
#     148     """Extract coefficients at specified timesteps t and conditioning data x.
#     149
#     150     Args:
#    (...)
#     158     a[t, x]: torch.Tensor: Torch tensor.
#     159     """
# --> 160     a = a.to(dtype=self.torch_dtype)
#     161     t_broadcast = t.unsqueeze(1).unsqueeze(-1).unsqueeze(-1)
#     163     # x.shape = (bs, height, width, channels)
#     164     # t_broadcast_shape = (bs, 1, 1, 1)
#     165     # a.shape = (num_timesteps, num_pixel_vals, num_pixel_vals)
#     166     # out.shape = (bs, height, width, channels, num_pixel_vals)
#     167     # out[i, j, k, l, m] = a[t[i, j, k, l], x[i, j, k, l], m]
#
# KeyboardInterrupt:
