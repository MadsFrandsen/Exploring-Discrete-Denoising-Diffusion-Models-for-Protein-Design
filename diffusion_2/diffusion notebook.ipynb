# %%
import os
import torch
import torchvision
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
# from torch.utils.tensorboard import summary
from torchvision import datasets, transforms
from torchvision.utils import save_image
from tqdm import tqdm

import matplotlib.pyplot as plt
import numpy as np

from model import UNet
from diffusion_discrete import DiscreteDiffusion, generate_betas

# %%
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)
# Out:
# device: cpu

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def imshow(img, w_shape=False):
    if w_shape:
        pimg = img.permute(1, 2, 0)
        npimg = pimg.numpy()
    else:
        npimg = img.numpy()
    plt.imshow(npimg, cmap='gray')
    plt.show()

# %%
# seed for reproducability
torch.manual_seed(50)

# training parameters
num_epochs = 10
batch_size = 128
lr = 2e-4
model = UNet(image_channels=1, model_output='logistic_pars').to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
print("Number of model parameters: ", count_parameters(model))
print(model)
# Out:
# Number of model parameters:  169043840
# UNet(
#   (image_proj): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (time_emb): TimeEmbedding(
#     (lin1): Linear(in_features=64, out_features=256, bias=True)
#     (act): Swish()
#     (lin2): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (down): ModuleList(
#     (0-1): 2 x DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Identity()
#         (time_emb): Linear(in_features=256, out_features=64, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (2): Downsample(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (3): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=128, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (4): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Identity()
#         (time_emb): Linear(in_features=256, out_features=128, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (5): Downsample(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (6): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=256, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (projection): Linear(in_features=256, out_features=768, bias=True)
#         (output): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (7): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Identity()
#         (time_emb): Linear(in_features=256, out_features=256, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (projection): Linear(in_features=256, out_features=768, bias=True)
#         (output): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (8): Downsample(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (9): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(256, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (projection): Linear(in_features=1024, out_features=3072, bias=True)
#         (output): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#     )
#     (10): DownBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Identity()
#         (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (projection): Linear(in_features=1024, out_features=3072, bias=True)
#         (output): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#     )
#   )
#   (middle): MiddleBlock(
#     (res1): ResidualBlock(
#       (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (act1): Swish()
#       (conv1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (act2): Swish()
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Identity()
#       (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#       (time_act): Swish()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (attn): AttentionBlock(
#       (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (projection): Linear(in_features=1024, out_features=3072, bias=True)
#       (output): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (res2): ResidualBlock(
#       (norm1): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (act1): Swish()
#       (conv1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (act2): Swish()
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (shortcut): Identity()
#       (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#       (time_act): Swish()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (up): ModuleList(
#     (0-1): 2 x UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 2048, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(2048, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=1024, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 1024, eps=1e-05, affine=True)
#         (projection): Linear(in_features=1024, out_features=3072, bias=True)
#         (output): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#     )
#     (2): UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 1280, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(1280, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=256, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (projection): Linear(in_features=256, out_features=768, bias=True)
#         (output): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (3): Upsample(
#       (conv): ConvTranspose2d(256, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (4-5): 2 x UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 512, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=256, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (projection): Linear(in_features=256, out_features=768, bias=True)
#         (output): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (6): UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 384, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=128, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): AttentionBlock(
#         (norm): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (projection): Linear(in_features=128, out_features=384, bias=True)
#         (output): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (7): Upsample(
#       (conv): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (8-9): 2 x UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 256, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=128, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (10): UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=64, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#     (11): Upsample(
#       (conv): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (12-14): 3 x UpBlock(
#       (res): ResidualBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (act1): Swish()
#         (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#         (act2): Swish()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (time_emb): Linear(in_features=256, out_features=64, bias=True)
#         (time_act): Swish()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (attn): Identity()
#     )
#   )
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): Swish()
#   (final): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
# change image size from 28 to 32 so that it is power of 2
img_size = 32

transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
])

trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True)

testset = datasets.MNIST(root='./data', train=False, transform=transform)
test_loader = DataLoader(testset, batch_size=batch_size, shuffle=False)

# %%
betas = generate_betas(type='cosine', start=0.02, stop=1., num_steps=1000).to(device)

# %%
diffusion = DiscreteDiffusion(betas=betas, transition_mat_type='uniform',
                              num_bits=8, transition_bands=None, model_prediction='x_start',
                              model_output='logistic_pars', loss_type='hybrid',
                              hybrid_coeff=0.001, device=device)
# Out:
# /Users/madsfrandsen/Documents/BSc_project/diffusion_2/diffusion_discrete.py:56: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.betas = betas = torch.tensor(betas, dtype=torch.float64)

# %%
train_losses = []
test_losses = []

for e in range(1, num_epochs+1):
    model.train()
    train_loss = 0
    train_loss_vals = []
    train_prior_bpd = 0
    for batch_idx, (x, _) in tqdm(enumerate(train_loader), total=len(train_loader)):
        x = x.to(device, dtype=torch.int32)
        # frame work expects data shape (B, H, W, C)
        x = x.permute(0, 2, 3, 1)

        optimizer.zero_grad()
        loss = diffusion.training_losses(model, x_start=x, rng=25).mean()
        prior_bpd = diffusion.prior_bpd(x).mean()

        loss.backward()
        train_loss += loss.item()
        train_loss_vals.append(loss.item())
        optimizer.step()

    train_loss /= batch_idx

    # evaluation
    model.eval()
    test_loss = 0
    test_loss_vals = []
    test_prior_bpd = 0
    test_total_bpd = 0
    with torch.no_grad():
        for batch_idx, (x_test, _) in enumerate(test_loader):
            x_test = x_test.to(device, dtype=torch.int32)
            x_test = x_test.permute(0, 2, 3, 1)

            l = diffusion.training_losses(model, x_test, rng=25).mean()
            test_loss += l.item()
            test_loss_vals.append(l.item())

            loss_dict = diffusion.calc_bpd_loop(model, x_start=x_test, rng=25)
            total_bpd = torch.mean(loss_dict['total'], dim=0)
            prior_bpd = torch.mean(loss_dict['prior'], axis=0)
    
    test_loss /= batch_idx

    train_losses.append(train_loss_vals)
    test_losses.append(test_loss_vals)

    print("\tEpoch,", e, "complete!", "\tTrain Loss: ", train_loss,
          "\tTest Loss: ", test_loss)
# Out:
#   0%|          | 1/469 [08:07<63:25:31, 487.89s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 15
#      12 x = x.permute(0, 2, 3, 1)
#      14 optimizer.zero_grad()
# ---> 15 loss = diffusion.training_losses(model, x_start=x, rng=25).mean()
#      16 prior_bpd = diffusion.prior_bpd(x).mean()
#      18 loss.backward()
#
# File ~/Documents/BSc_project/diffusion_2/diffusion_discrete.py:561, in DiscreteDiffusion.training_losses(self, model_fn, x_start, rng)
#     556     losses = self.cross_entropy_start(
#     557         x_start=x_start, pred_x_start_logits=pred_x_start_logits)
#     559 elif self.loss_type == 'hybrid':
#     560     # Optimizes L_vb - lambda * sum_x_start x_start log pred_x_start.
# --> 561     vb_losses, pred_x_start_logits = self.vb_terms_bpd(
#     562         model_fn=model_fn, x_start=x_start, x_t=x_t, t=t)
#     563     ce_losses = self.cross_entropy_start(
#     564         x_start=x_start, pred_x_start_logits=pred_x_start_logits)
#     565     losses = vb_losses + self.hybrid_coeff * ce_losses
#
# File ~/Documents/BSc_project/diffusion_2/diffusion_discrete.py:463, in DiscreteDiffusion.vb_terms_bpd(self, model_fn, x_start, x_t, t)
#     448 """Calculate specified terms of the variational bound.
#     449
#     450 Args:
#    (...)
#     460     the denoised image.
#     461 """
#     462 true_logits = self.q_posterior_logits(x_start, x_t, t, x_start_logits=False)
# --> 463 model_logits, pred_x_start_logits = self.p_logits(model_fn, x=x_t, t=t)
#     465 kl = utils.categorical_kl_logits(logits1=true_logits, logits2=model_logits)
#     466 assert kl.shape == x_start.shape
#
# File ~/Documents/BSc_project/diffusion_2/diffusion_discrete.py:355, in DiscreteDiffusion.p_logits(self, model_fn, x, t)
#     348     pred_x_start_logits = model_logits
#     351     t_broadcast = t.unsqueeze(1).unsqueeze(-1).unsqueeze(-1).unsqueeze(-1)
#     353     model_logits = torch.where(t_broadcast == 0,
#     354                                pred_x_start_logits,
# --> 355                                self.q_posterior_logits(pred_x_start_logits, x,
#     356                                                        t, x_start_logits=True)
#     357                                 )
#     359 elif self.model_prediction == 'xprev':
#     360     # Use the logits out of the model directly as the logits for
#     361     # p(x_{t-1}|x_t). model_logits are already set correctly.
#    (...)
#     365     # q(x_{t-1}}|x_t, x_0) to compute the predicted x_0/x_start.
#     366     # The equivalent for the categorical case is nontrivial.
#     367     pred_x_start_logits = model_logits
#
# File ~/Documents/BSc_project/diffusion_2/diffusion_discrete.py:314, in DiscreteDiffusion.q_posterior_logits(self, x_start, x_t, t, x_start_logits)
#     311 fact1 = self._at(self.transpose_q_onestep_mats, t, x_t)
#     312 if x_start_logits:
#     313     # PyTorch's softmax operates on the specified dimension.
# --> 314     fact2 = self._at_onehot(self.q_mats, t-1, F.softmax(x_start, dim=-1))
#     315     tzero_logits = x_start
#     316 else:
#
# File ~/Documents/BSc_project/diffusion_2/diffusion_discrete.py:238, in DiscreteDiffusion._at_onehot(self, a, t, x)
#     233 a = a.to(dtype=self.torch_dtype)
#     235 # x.shape = (bs, height, width, channels, num_pixel_vals)
#     236 # a[t]shape = (bs, num_pixel_vals, num_pixel_vals)
#     237 # out.shape = (bs, height, width, channels, num_pixel_vals)
# --> 238 return torch.matmul(x, a[t, None, None, Ellipsis])
#
# KeyboardInterrupt:

# %%
plt.plot(np.arange(1, num_epochs+1), [np.mean(ls) for ls in train_losses], lw=2.5, label='train')
plt.plot(np.arange(1, num_epochs+1), [np.mean(ls) for ls in test_losses], lw=2.5, label='test')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.yscale('log')
plt.title('Average training/test loss per epoch')
plt.legend()
plt.show()
